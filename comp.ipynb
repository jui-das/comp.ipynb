# %% [markdown]
# **comparison**

# %%
print(10 > 109)
print(100> 99)
print(9<10)
# Out:
# False
# True
# True

# %%
a = 10
b = 10
print("equal to : ", a==b)

a=20
b=30
print("equal to :", a==b)
print(20==30)
print("not equal to :", 20!=30) #notequalto (!=)
print("greater than :", a>b)
print("greater than or equal to :", a>=b)
print("less than :", a<b)
print("less than or equal to :", a<=b)
# Out:
# equal to :  True
# equal to : False
# False
# not equal to : True
# greater than : False
# greater than or equal to : False
# less than : True
# less than or equal to : True

# %%
current = int(input("Enter the current balance :"))
balance = 10000
print(current > balance)
# Out:
# Enter the current balance :2000
# False

# %% [markdown]
# **logical operator**

# %%
"""
string operator,logical,logic
and
or
not
"""
print(10>9 and 9>6 and 10==10 and 100>99)
# Out:
# True

# %%
age = int(input("Enter your age :"))
has_id = True
print((age >=18) and (has_id ==True))
# Out:
# Enter your age :23
# True

# %%
#LOGICAL OR OPERATOR
marks = int(input("Enter marks :"))
print(marks >40 or marks >=35)
# Out:
# Enter marks :42
# True

# %%
is_logged_in = False
print(not is_logged_in)
# Out:
# True

# %%
#assignment
x = 5
x+=100
print(x)
x = 10000
x -=345
print(x)
msg = 656
msg *=2
print(msg)

a = "helloworld"
a += "!"
print(a)

a = 567
a /=7
print(a)

a= 56
a //=9
print(a)
# Out:
# 105
# 9655
# 1312
# helloworld!
# 81.0
# 6
